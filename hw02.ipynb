# %% [markdown]
# # BEE 4750 Homework 2: Systems Modeling and Simulation
#
# **Name**: Raashid Husain
#
# **ID**: RAH383
#
# > **Due Date**
# >
# > Thursday, 09/19/24, 9:00pm
#
# ## Overview
#
# ### Instructions
#
# -   Problem 1 asks you to derive a model for water quality in a river
#     system and use this model to check for regulatory compliance.
# -   Problem 2 asks you to explore the dynamics and equilibrium stability
#     of the shallow lake model under a particular set of parameter
#     values.
# -   Problem 3 (5750 only) asks you to modify the lake eutrophication
#     example from Lecture 04 to account for atmospheric deposition.
#
# ### Load Environment
#
# The following code loads the environment and makes sure all needed
# packages are installed. This should be at the start of most Julia
# scripts.

# %%
import Pkg
Pkg.activate(@__DIR__)
Pkg.instantiate()
# Out:
#   Activating project at `~/Downloads/BEE 4750/hw2-rah383`
#    Installed Libmount_jll ────────────── v2.35.0+0
#    Installed LoggingExtras ───────────── v1.0.0
#    Installed Accessors ───────────────── v0.1.37
#    Installed Preferences ─────────────── v1.4.0
#    Installed Xorg_xkbcomp_jll ────────── v1.4.2+4
#    Installed GR_jll ──────────────────── v0.72.7+0
#    Installed JpegTurbo_jll ───────────── v2.1.91+0
#    Installed RelocatableFolders ──────── v1.0.0
#    Installed Unitful ─────────────────── v1.14.0
#    Installed Formatting ──────────────── v0.4.2
#    Installed InlineStrings ───────────── v1.4.0
#    Installed ConcurrentUtilities ─────── v2.2.0
#    Installed Contour ─────────────────── v0.6.2
#    Installed PlotUtils ───────────────── v1.3.5
#    Installed ColorSchemes ────────────── v3.21.0
#    Installed InvertedIndices ─────────── v1.3.0
#    Installed Xorg_libpthread_stubs_jll ─ v0.1.0+3
#    Installed OpenSSL ─────────────────── v1.4.1
#    Installed Roots ───────────────────── v2.1.6
#    Installed HTTP ────────────────────── v1.9.7
#    Installed DataFrames ──────────────── v1.6.1
#    Installed Cairo_jll ───────────────── v1.16.1+1
#    Installed Libgpg_error_jll ────────── v1.42.0+0
#    Installed Fontconfig_jll ──────────── v2.13.93+0
#    Installed Qt5Base_jll ─────────────── v5.15.3+2
#    Installed Missings ────────────────── v1.1.0
#    Installed Xorg_libxkbfile_jll ─────── v1.1.0+4
#    Installed Xorg_libXau_jll ─────────── v1.0.9+4
#    Installed GR ──────────────────────── v0.72.7
#    Installed LZO_jll ─────────────────── v2.10.1+0
#    Installed Bzip2_jll ───────────────── v1.0.8+0
#    Installed xkbcommon_jll ───────────── v1.4.1+0
#    Installed PlotThemes ──────────────── v3.1.0
#    Installed SentinelArrays ──────────── v1.4.3
#    Installed SpecialFunctions ────────── v2.3.0
#    Installed WorkerUtilities ─────────── v1.6.1
#    Installed FriBidi_jll ─────────────── v1.0.10+0
#    Installed WeakRefStrings ──────────── v1.4.2
#    Installed Colors ──────────────────── v0.12.10
#    Installed TranscodingStreams ──────── v0.9.13
#    Installed fzf_jll ─────────────────── v0.29.0+0
#    Installed GLFW_jll ────────────────── v3.3.8+0
#    Installed MbedTLS ─────────────────── v1.1.7
#    Installed DataStructures ──────────── v0.18.13
#    Installed FreeType2_jll ───────────── v2.10.4+0
#    Installed JLFzf ───────────────────── v0.1.5
#    Installed StatsAPI ────────────────── v1.6.0
#    Installed CodecZlib ───────────────── v0.7.1
#    Installed Compat ──────────────────── v4.7.0
#    Installed StatsBase ───────────────── v0.34.0
#    Installed libpng_jll ──────────────── v1.6.38+0
#    Installed Xorg_libxcb_jll ─────────── v1.13.0+3
#    Installed libaom_jll ──────────────── v3.4.0+0
#    Installed ExceptionUnwrapping ─────── v0.1.9
#    Installed ColorTypes ──────────────── v0.11.4
#    Installed Xorg_libXext_jll ────────── v1.3.4+4
#    Installed Zstd_jll ────────────────── v1.5.5+0
#    Installed Expat_jll ───────────────── v2.5.0+0
#    Installed Scratch ─────────────────── v1.2.0
#    Installed PrettyTables ────────────── v2.3.2
#    Installed PooledArrays ────────────── v1.4.3
#    Installed Plots ───────────────────── v1.38.16
#    Installed Parsers ─────────────────── v2.7.1
#    Installed Xorg_libXrender_jll ─────── v0.9.10+4
#    Installed Libtiff_jll ─────────────── v4.4.0+0
#    Installed ConstructionBase ────────── v1.5.2
#    Installed JLLWrappers ─────────────── v1.4.1
#    Installed CompositionsBase ────────── v0.1.2
#    Installed ColorVectorSpace ────────── v0.9.10
#    Installed OpenSpecFun_jll ─────────── v0.5.5+0
#    Installed OrderedCollections ──────── v1.6.0
#    Installed CSV ─────────────────────── v0.10.14
#    Installed LogExpFunctions ─────────── v0.3.24
#    Installed MacroTools ──────────────── v0.5.10
#    Installed ChainRulesCore ──────────── v1.24.0
#    Installed CommonSolve ─────────────── v0.2.4
#    Installed Libuuid_jll ─────────────── v2.36.0+0
#    Installed Pixman_jll ──────────────── v0.42.2+0
#    Installed Crayons ─────────────────── v4.1.1
#    Installed Latexify ────────────────── v0.16.1
#    Installed Wayland_protocols_jll ───── v1.25.0+0
#    Installed InverseFunctions ────────── v0.1.15
#    Installed XML2_jll ────────────────── v2.10.3+0
#    Installed Libgcrypt_jll ───────────── v1.8.7+0
#    Installed Xorg_xtrans_jll ─────────── v1.4.0+3
#    Installed OpenSSL_jll ─────────────── v1.1.21+0
#    Installed BitFlags ────────────────── v0.1.7
#    Installed Wayland_jll ─────────────── v1.21.0+0
#    Installed FFMPEG_jll ──────────────── v4.4.2+2
#    Installed LAME_jll ────────────────── v3.100.1+0
#    Installed Xorg_xkeyboard_config_jll ─ v2.27.0+4
#    Installed DataAPI ─────────────────── v1.15.0
#    Installed FixedPointNumbers ───────── v0.8.4
#    Installed Libiconv_jll ────────────── v1.16.1+2
#    Installed LLVMOpenMP_jll ──────────── v15.0.4+0
#    Installed URIs ────────────────────── v1.4.2
#    Installed PrecompileTools ─────────── v1.1.2
#    Installed FilePathsBase ───────────── v0.9.21
#    Installed StringManipulation ──────── v0.3.4
#    Installed Xorg_libXdmcp_jll ───────── v1.1.3+4
#    Installed Glib_jll ────────────────── v2.74.0+2
#    Installed LaTeXStrings ────────────── v1.3.0
#    Installed Xorg_libX11_jll ─────────── v1.6.9+4
#    Installed SortingAlgorithms ───────── v1.1.1
# Precompiling project...
#   ✓ LaTeXStrings
#   ✓ WorkerUtilities
#   ✓ Contour
#   ✓ StatsAPI
#   ✓ CommonSolve
#   ✓ InverseFunctions
#   ✓ ConcurrentUtilities
#   ✓ SentinelArrays
#   ✓ Preferences
#   ✓ Compat
#   ✓ OrderedCollections
#   ✓ MbedTLS
#   ✓ CompositionsBase
#   ✓ URIs
#   ✓ Formatting
#   ✓ ExceptionUnwrapping
#   ✓ InvertedIndices
#   ✓ MacroTools
#   ✓ ConstructionBase
#   ✓ TranscodingStreams
#   ✓ DataAPI
#   ✓ BitFlags
#   ✓ Scratch
#   ✓ LoggingExtras
#   ✓ LogExpFunctions
#   ✓ Crayons
#   ✓ InverseFunctions → DatesExt
#   ✓ PrecompileTools
#   ✓ JLLWrappers
#   ✓ Compat → CompatLinearAlgebraExt
#   ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#   ✓ CodecZlib
#   ✓ FixedPointNumbers
#   ✓ PooledArrays
#   ✓ Missings
#   ✓ Tables
#   ✓ RelocatableFolders
#   ✓ RecipesBase
#   ✓ Latexify
#   ✓ StringManipulation
#   ✓ Graphite2_jll
#   ✓ OpenSSL_jll
#   ✓ Libmount_jll
#   ✓ EpollShim_jll
#   ✓ Bzip2_jll
#   ✓ LLVMOpenMP_jll
#   ✓ Xorg_libXau_jll
#   ✓ libpng_jll
#   ✓ libfdk_aac_jll
#   ✓ LAME_jll
#   ✓ LERC_jll
#   ✓ fzf_jll
#   ✓ JpegTurbo_jll
#   ✓ Xorg_libXdmcp_jll
#   ✓ Ogg_jll
#   ✓ x264_jll
#   ✓ x265_jll
#   ✓ libaom_jll
#   ✓ Zstd_jll
#   ✓ LZO_jll
#   ✓ Expat_jll
#   ✓ Xorg_xtrans_jll
#   ✓ Opus_jll
#   ✓ Libiconv_jll
#   ✓ Libffi_jll
#   ✓ Wayland_protocols_jll
#   ✓ Libgpg_error_jll
#   ✓ Xorg_libpthread_stubs_jll
#   ✓ OpenSpecFun_jll
#   ✓ FriBidi_jll
#   ✓ Libuuid_jll
#   ✓ ChainRulesCore
#   ✓ FilePathsBase
#   ✓ DataStructures
#   ✓ Accessors
#   ✓ ColorTypes
#   ✓ FreeType2_jll
#   ✓ OpenSSL
#   ✓ Pixman_jll
#   ✓ JLFzf
#   ✓ libvorbis_jll
#   ✓ XML2_jll
#   ✓ Libtiff_jll
#   ✓ Libgcrypt_jll
#   ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#   ✓ SortingAlgorithms
#   ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#   ✓ Unitful
#   ✓ Parsers
#   ✓ Fontconfig_jll
#   ✓ Wayland_jll
#   ✓ Gettext_jll
#   ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#   ✓ XSLT_jll
#   ✓ Colors
#   ✓ Unitful → InverseFunctionsUnitfulExt
#   ✓ Accessors → AccessorsUnitfulExt
#   ✓ InlineStrings
#   ✓ Glib_jll
#   ✓ JSON
#   ✓ Xorg_libxcb_jll
#   ✓ HTTP
#   ✓ WeakRefStrings
#   ✓ Xorg_xcb_util_jll
#   ✓ SpecialFunctions
#   ✓ StatsBase
#   ✓ Xorg_libX11_jll
#   ✓ Xorg_xcb_util_image_jll
#   ✓ Xorg_xcb_util_keysyms_jll
#   ✓ Roots
#   ✓ Xorg_xcb_util_renderutil_jll
#   ✓ Xorg_xcb_util_wm_jll
#   ✓ PrettyTables
#   ✓ Xorg_libXrender_jll
#   ✓ Xorg_libXext_jll
#   ✓ Xorg_libXfixes_jll
#   ✓ Xorg_libxkbfile_jll
#   ✓ Libglvnd_jll
#   ✓ Xorg_libXinerama_jll
#   ✓ Xorg_libXrandr_jll
#   ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#   ✓ Xorg_libXcursor_jll
#   ✓ Xorg_libXi_jll
#   ✓ Xorg_xkbcomp_jll
#   ✓ GLFW_jll
#   ✓ Xorg_xkeyboard_config_jll
#   ✓ xkbcommon_jll
#   ✓ Cairo_jll
#   ✓ ColorVectorSpace
#   ✓ Qt5Base_jll
#   ✓ HarfBuzz_jll
#   ✓ libass_jll
#   ✓ FFMPEG_jll
#   ✓ ColorSchemes
#   ✓ FFMPEG
#   ✓ CSV
#   ✓ GR_jll
#   ✓ GR
#   ✓ PlotUtils
#   ✓ PlotThemes
#   ✓ RecipesPipeline
#   ✓ DataFrames
#   ✓ Latexify → DataFramesExt
#   ✓ UnitfulLatexify
#   ✓ Plots
#   ✓ Plots → UnitfulExt
#   146 dependencies successfully precompiled in 164 seconds. 25 already precompiled.

# %%
using Plots
using LaTeXStrings
using CSV
using DataFrames
using Roots

# %% [markdown]
# ## Problems (Total: 50/60 Points)

# %% [markdown]
# ### Problem 1 (25 points)
#
# A river which flows at 10 km/d is receiving discharges of wastewater
# contaminated with CRUD from two sources which are 15 km apart, as shown
# in the Figure below. CRUD decays exponentially in the river at a rate of
# 0.36 $\mathrm{d}^{-1}$.

# %% [markdown]
# <figure>
# <img src="attachment:figures/river_diagram.png"
# alt="Schematic of the river system in Problem 1" />
# <figcaption aria-hidden="true">Schematic of the river system in Problem
# 1</figcaption>
# </figure>

# %% [markdown]
# **In this problem**:
#
# -   Assuming steady-state conditions, derive a model for the
#     concentration of CRUD downriver by solving the appropriate
#     differential equation(s) analytically.
# -   Determine if the system in compliance with a regulatory limit of 2.5
#     kg/(1000 m$^3$).

# %% [markdown]
# #### Problem 1 was handwritten and will be attached via screenshots in the homework report.

# %% [markdown]
# > **Tip**
# >
# > Formulate your model in terms of distance downriver, rather than
# > leaving it in terms of time from discharge.
#
# ### Problem 2 (25 points)
#
# Consider the shallow lake model from class:
#
# $$
# \begin{aligned}
# X_{t+1} &= X_t + a_t + y_t + \frac{X_t^q}{1 + X_t^q} - bX_t, \\
# y_t &\sim \text{LogNormal}(\mu, \sigma^2),
# \end{aligned}
# $$
#
# where:
#
# -   $X_t$ is the lake phosphorous (P) concentration at time $t$;
# -   $a_t$ is the point-source P release at time $t$;
# -   $y_t$ is the non-point-source P release at time $t$, which is
#     treated as random from a LogNormal distribution with mean $\mu$ and
#     standard deviation $\sigma$;
# -   $b$ is the linear rate of P outflow;
# -   $q$ is a parameter influencing the rate of P recycling from the
#     sediment.
#
# **In this problem**:
#
# -   Make an initial conditions plot for the model dynamics for $b=0.5$,
#     $q=1.5$, $y_t=0$, and $a_t=0$ for $t=0, \ldots, 30$. What are the
#     equilibria? What can you say about the resilience of the system?
#
#     > **Finding equilibria**
#     >
#     > Use [`Roots.jl`](https://juliamath.github.io/Roots.jl/stable/) to
#     > find the equilibria by solving for values where $X_{t+1} = X_t$.
#     > For example, if you have functions `X_outflow(X,b)` and
#     > `X_recycling(X,q)`, you could create a function
#     > `X_delta(x, a) = a + X_recycling(x) - X_outflow(x)` and call
#     > `Roots.find_zero(x -> X_delta(x, a), x₀)`, where `x₀` is an
#     > initial value for the search (you might need to use your plot to
#     > find values for `x₀` near each of the “true” equilibria).
#
# -   Repeat the analysis with $a_t=0.02$ for all $t$. What are the new
#     equilibria? How have the dynamics and resilience of the system
#     changed?

# %%
# define functions for lake recycling and outflows
X_recycling(X, q) = X.^q ./ (1 .+ X.^q);
X_outflow(X, b) = b .* X;

T = 30
X_vals = collect(0.0:0.1:2.0)
function simulate_lake_X(X_ic, T, b, q, a, y)
    X = zeros(T)
    X[1] = X_ic
    for t = 2:T
        X[t] = X[t-1] .+ a[t] .+ y[t].+ X_recycling(X[t-1], q) .- X_outflow(X[t-1], b)
    end
    return X
end

X = map(x -> simulate_lake_X(x, T, 0.5, 1.5, zeros(T), zeros(T)), X_vals)
p_noinflow = plot(X, label=false, ylabel=L"X_t", xlabel="Time", guidefontsize=18, tickfontsize=16, size=(600, 500))

# %%
# define range of X
x = 0:0.05:2;

X_delta(x, a) = a + X_recycling(x, 1.5) - X_outflow(x, 0.5)
x01 = 0
x02 = 0.5
x03 = 1.0
root1 = (Roots.find_zero(x -> X_delta(x, 0),x01))
root2 = (Roots.find_zero(x -> X_delta(x, 0),x02))
root3 = (Roots.find_zero(x -> X_delta(x, 0),x03))

# plot recycling and outflows for selected values of b and q
p1 = plot(x, X_recycling(x, 1.5), color=:black, linewidth=5,legend=:topleft, label="X Recycling", ylabel="X Flux", xlabel=L"$X_t$", tickfontsize=16, guidefontsize=18, legendfontsize=16, palette=:tol_muted, framestyle=:zerolines, grid=:false)
plot!(x, X_outflow(x, 0.5), linewidth=3, linestyle=:dash, label=L"$b=0.5$", color=:blue)
plot!(ylims=(-0.02, .75))
plot!(size=(600, 500))
print("The equilibria points are at:", '\n')
print(root1, '\n')
print(root2, '\n')
print(root3, '\n')

display(p1)
# Out:
# The equilibria points are at:
# 0.0
# 0.3819660112501051
# 1.0

# %% [markdown]
# ##### Code and Results Discussion:
#
# The code is mostly adapted from the lecture slides and I used the described root finding method to find the equilibria points. Since the equilibria points are from the intersection of 'b' and the amount recycled, this was a relatively easy formulation.
#
# The first plot shows the lake dynamics with no inflows on a macroscopic scale over time. The second graph is a better way to see the equilibria points which are listed below the graph.
#
# To answer the questions posed by the problem, I can say that the system is not very resilient because, in terms of eutrophication, the lake would eutrophy quite quickly if $X_t$ increases slightly past 0.3 as the equilibria suggests. If it passes that point, the system will definietely converge to a higher $X_t$ and there isn't much wiggle room to return to normal conditions

# %% [markdown]
# ## References
#
# List any external references consulted, including classmates.
